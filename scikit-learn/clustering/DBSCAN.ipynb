# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiscu/data-science-use-cases/blob/main/scikit-learn/clustering/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN

# %%
# create specific use-case of clustering between 2 regions
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.tight_layout()
plt.show()

# %%
def show_clustering(method, X, n_clusters):
    if method=="k-Means":
        model = KMeans(n_clusters=n_clusters, n_init=10, random_state=0)
    elif method=="Agglomerative":
        model = AgglomerativeClustering(n_clusters=n_clusters, metric='euclidean', linkage='complete')
    elif method=="DBSCAN":
        model = DBSCAN(eps=0.2, min_samples=5, metric='euclidean')

    y = model.fit_predict(X)
    plt.scatter(X[y==0, 0], X[y==0, 1],
        c='lightblue', marker='o', s=40, edgecolor='black',  label='Cluster 1')
    plt.scatter(X[y==1, 0], X[y==1, 1],
        c='red', marker='s', s=40, edgecolor='black', label='Cluster 2')
    plt.title(f'{method} Clustering')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend()
    plt.tight_layout()
    plt.show()

show_clustering("k-Means", X, 2)
show_clustering("Agglomerative", X, 2)
show_clustering("DBSCAN", X, 2)
